# %%
'Thanks for the help hopefully you can understand what Im doing.Im sure the early stuff is pretty inefficient, using frames and what not, so bear with the cringe'
# Out:
# 'Thanks for the help hopefully you can understand what Im doing.Im sure the early stuff is pretty inefficient, using frames and what not, so bear with the cringe'

# %%
import pandas as pd  
from random import random
import numpy as np
import scipy
# Out:
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.

# %%
basicmatchinfo=pd.read_csv('Basic_Match_Info_Update.csv',header=-1)
detailedgamedata=pd.read_csv('Detailed_Game_Data.csv',header=0)

# %%
detailedgamedata
# Out:
#         ID                                               Link  MatchID  \
# 0        2  http://www.hltv.org/match/2292372-cloud9-nip-e...     6234
# 1        3  http://www.hltv.org/match/2292372-cloud9-nip-e...     6234
# 2        4  http://www.hltv.org/match/2292372-cloud9-nip-e...     6234
# 3        5  http://www.hltv.org/match/2292374-fnatic-digni...     6235
# 4        6  http://www.hltv.org/match/2292374-fnatic-digni...     6235
# 5        7  http://www.hltv.org/match/2292377-ldlc-nip-esl...     6236
# 6        8  http://www.hltv.org/match/2292377-ldlc-nip-esl...     6236
# 7        9  http://www.hltv.org/match/2292377-ldlc-nip-esl...     6236
# 8       10  http://www.hltv.org/match/2292378-moldova-luxe...     6237
# 9       11  http://www.hltv.org/match/2292378-moldova-luxe...     6237
# 10      12  http://www.hltv.org/match/2292382-fnatic-nip-e...     6238
# 11      13  http://www.hltv.org/match/2292382-fnatic-nip-e...     6238
# 12      14  http://www.hltv.org/match/2292382-fnatic-nip-e...     6238
# 13      15  http://www.hltv.org/match/2292379-malta-armeni...     6239
# 14      16  http://www.hltv.org/match/2292379-malta-armeni...     6239
# 15      17  http://www.hltv.org/match/2292381-macedonia-gr...     6241
# 16      18  http://www.hltv.org/match/2292381-macedonia-gr...     6241
# 17      19  http://www.hltv.org/match/2292381-macedonia-gr...     6241
# 18      20  http://www.hltv.org/match/2292391-mousesports-...     6246
# 19      21  http://www.hltv.org/match/2292392-no-sir-myxmg...     6250
# 20      22  http://www.hltv.org/match/2292392-no-sir-myxmg...     6250
# 21      23  http://www.hltv.org/match/2292380-slovenia-far...     6251
# 22      24  http://www.hltv.org/match/2292380-slovenia-far...     6251
# 23      25  http://www.hltv.org/match/2292398-mousesports-...     6256
# 24      26  http://www.hltv.org/match/2292398-mousesports-...     6256
# 25      27  http://www.hltv.org/match/2292398-mousesports-...     6256
# 26      28  http://www.hltv.org/match/2292402-no-sir-nosta...     6257
# 27      29  http://www.hltv.org/match/2292402-no-sir-nosta...     6257
# 28      30  http://www.hltv.org/match/2292402-no-sir-nosta...     6257
# 29      31  http://www.hltv.org/match/2292403-nip-encore-c...     6260
# ...    ...                                                ...      ...
# 6533  6535  http://www.hltv.org/match/2298883-alientech-bu...    12526
# 6534  6536  http://www.hltv.org/match/2298884-arcade-gus-g...    12527
# 6535  6537  http://www.hltv.org/match/2298884-arcade-gus-g...    12527
# 6536  6538  http://www.hltv.org/match/2298879-xenex-uesmas...    12528
# 6537  6539  http://www.hltv.org/match/2298879-xenex-uesmas...    12528
# 6538  6540  http://www.hltv.org/match/2298872-hellraisers-...    12529
# 23          dust2          1       mousesports            myXMG  1   10   16
# 24         mirage          2       mousesports            myXMG  0   16    4
# 25       overpass          3       mousesports            myXMG  0   16    7
# 26          cache          1           NO SIR!        Nostalgie  1    9   16
# 27        inferno          2           NO SIR!        Nostalgie  0   16   11
# 28         mirage          3           NO SIR!        Nostalgie  0   16    4
# 29           nuke          1               NiP           ENCORE  0   16    3
# ...           ...        ...               ...              ... ..  ...  ...
# 6533       mirage          2         AlienTech  BulletsRage.Pro  0   16    7
# 6534       mirage          1            Arcade       GUS-Gaming  0   16    7
# 6535        cache          2            Arcade       GUS-Gaming  0   16   12
# 6536        cache          1             XENEX          UESmash  1   11   16
# 6537        dust2          2             XENEX          UESmash  1    3   16
# 6538       mirage          1       HellRaisers               SK  1    6   16
# 6539        dust2          1               NiP            Titan  1   17   19
# 6540      inferno          1              k1ck  BulletsRage.Pro  1   11   16
# 6541       mirage          1                SK    Natus Vincere  1   13   16
# 6542  cobblestone          1                SK       Virtus.pro  1   13   16
# 6543        dust2          1               ACG             Enso  1    8   16
# 6544       mirage          2               ACG             Enso  0   16   14
# 6545        train          3               ACG             Enso  0   16   14
# 6546        cache          1  European Misfits         Reaction  0   16    5
# 6547        dust2          2  European Misfits         Reaction  0   16   14
# 6548     overpass          1        Virtus.pro              TSM  1    3   16
# 6549       mirage          1        GUS-Gaming             Enso  1   13   16
# 6550      inferno          1               TSM           EnVyUs  0   16    9
# 6551        train          1        Keyd Stars        AlienTech  0   16   12
# 6552      inferno          2        Keyd Stars        AlienTech  1   15   19
# 6553       mirage          3        Keyd Stars        AlienTech  1   22   25
# 6554        dust2          1        Luminosity            Enemy  0   16   11
# 6555      inferno          1      Leader-1 Red          Quintic  0   16    8
# 6556        cache          1        Luminosity        Coastless  0   19   17
# 6557        cache          1               SoF             Gosu  0   16    8
# 6558        dust2          2               SoF             Gosu  0   16    8
# 6559       mirage          1            Cloud9              CLG  1   11   16
# 6560     overpass          1            Cloud9            Enemy  1   10   16
# 6561        dust2          1            Liquid        Coastless  0   16   10
# 6562      inferno          1      Leader-1 Red             Gosu  1   13   16
#
#       ...    1.83   1.84  1.85   1.86  1.87   1.88  1.89   1.90   1.91   1.92
# 0     ...    26.3  Empty  35.3  Empty  50.0  Empty  40.0  Empty   41.7  18:30
# 1     ...    43.3  Empty  54.6  Empty  40.9  Empty  50.0  Empty   25.0  18:30
# 2     ...    45.2  Empty  30.8  Empty  24.0  Empty  13.3  Empty   23.1  18:30
# 3     ...    41.2  Empty  23.5  Empty  50.0  Empty  50.0  Empty   60.0  09:20
# 4     ...    37.0  Empty  41.7  Empty  36.8  Empty  50.0  Empty   60.0  09:20
# 5     ...    55.0  Empty  41.2  Empty  35.7  Empty  64.3  Empty   62.5  11:55
# 6     ...    40.7  Empty  22.7  Empty  44.4  Empty  35.7  Empty   45.5  11:55
# 7     ...    25.0  Empty  47.8  Empty  60.9  Empty  23.8  Empty   40.0  11:55
# 8     ...    66.7  Empty  50.0  Empty  50.0  Empty  60.0  Empty   50.0  17:00
# 6544  ...    52.2  Empty  30.4  Empty  47.1  Empty  63.2  Empty   28.6  19:00
# 6545  ...    24.0  Empty   4.4  Empty  36.8  Empty  33.3  Empty   38.5  19:00
# 6546  ...    50.0  Empty  70.0  Empty  50.0  Empty  40.0  Empty   50.0  20:00
# 6547  ...    33.3  Empty  65.0  Empty  72.2  Empty  43.8  Empty   66.7  20:00
# 6548  ...    20.0  Empty  47.4  Empty  42.1  Empty  35.3  Empty   42.9  21:20
# 6549  ...    21.4  Empty  47.8  Empty  45.5  Empty  57.1  Empty   62.5  22:00
# 6550  ...    55.0  Empty  42.1  Empty  46.7  Empty  53.3  Empty   81.8  22:00
# 6551  ...    57.1  Empty  73.7  Empty  43.8  Empty  29.4  Empty   33.3  20:30
# 6552  ...    42.9  Empty  59.3  Empty  21.7  Empty  35.0  Empty   56.3  20:30
# 6553  ...    39.1  Empty  63.4  Empty  50.0  Empty  54.6  Empty   57.9  20:30
# 6554  ...    23.8  Empty  80.0  Empty  44.4  Empty  57.1  Empty   64.3  00:00
# 6555  ...    58.8  Empty  78.6  Empty  36.4  Empty  50.0  Empty   45.5  01:00
# 6556  ...    53.3  Empty  25.9  Empty  40.0  Empty  29.2  Empty   41.7  01:00
# 6557  ...    33.3  Empty  37.5  Empty  75.0  Empty  30.0  Empty   45.5  01:15
# 6558  ...    57.9  Empty  40.0  Empty  14.3  Empty  66.7  Empty   41.7  01:15
# 6559  ...    46.7  Empty  28.0  Empty  33.3  Empty  50.0  Empty   38.5  02:00
# 6560  ...    48.0  Empty  35.0  Empty  59.1  Empty  57.1  Empty   41.7  01:00
# 6561  ...    43.5  Empty  36.4  Empty  62.5  Empty  57.1  Empty   80.0  03:00
# 6562  ...    58.6  Empty  19.1  Empty  61.9  Empty  23.5  Empty   62.5  03:00
#
# [6563 rows x 100 columns]

# %%
basicmatchinfo
# Out:
#                      0                1   2                  3   4   5     6   \
# 0                Cloud9              NiP   1                NiP   1   2   958
# 1                fnatic         dignitas   0             fnatic   2   0   959
# 2                   NiP             LDLC   0                NiP   2   1   959
# 3               Moldova       Luxembourg   0            Moldova   2   0   959
# 4                fnatic              NiP   1                NiP   1   2   959
# 5                 Malta          Armenia   0              Malta   2   0   959
# 6                  SKDC          LunatiK   0               SKDC  16   7   960
# 7             Macedonia           Greece   0          Macedonia   2   1   960
# 8     NetcodeGuides.com         RELiABLE   0  NetcodeGuides.com  16  10   964
# 9     NetcodeGuides.com             SKDC   0  NetcodeGuides.com  16   9   964
# 10              LunatiK            Tempo   0            LunatiK  16  14   964
# 11               savage             SKDC   0             savage  16   7   964
# 12          mousesports          Epsilon   0        mousesports   2   0   964
# 13                OHYEA          Infused   1            Infused   1  16   964
# 14             thechaps              TGM   1                TGM  12  16   964
# 15             dignitas          Epsilon   0           dignitas  16  11   964
# 16                myXMG          NO SIR!   0              myXMG   2   0   964
# 17             Slovenia    Faroe Islands   0           Slovenia   2   0   964
# 18              Infused              TGM   0            Infused   2   0   964
# 19               Global            Tempo   0             Global  16   7   964
# 20    NetcodeGuides.com       Justus Pro   0  NetcodeGuides.com  16  13   964
# 21              LunatiK         RELiABLE   0            LunatiK  16   4   964
# 22          mousesports            myXMG   0        mousesports   2   1   964
# 23              NO SIR!        Nostalgie   0            NO SIR!   2   1   964
# 24    NetcodeGuides.com        iBUYPOWER   0  NetcodeGuides.com  16   4   964
# 25              LunatiK             SKDC   0            LunatiK  16  12   964
# 26                  NiP           ENCORE   0                NiP   2   0   964
# 27                myXMG          NO SIR!   0              myXMG   2   0   964
# 28          neXtPlease!          Airwalk   0        neXtPlease!  16   3   964
# 29    London Conspiracy      mousesports   1        mousesports   1   2   964
# ...                 ...              ...  ..                ...  ..  ..   ...
# 6284      Vega Squadron              ttc   0      Vega Squadron   2   0  1391
# 6285         LDLC White            DenDD   1              DenDD   1   1  1391
# 6286        KoN Finland      KoN Denmark   0        KoN Finland  16   2  1391
# 6287           FlipSid3             CSGL   0           FlipSid3   2   1  1391
# 6288                SoF     Leader-1 Red   0                SoF   2   1  1393
# 6289               Gosu          Quintic   0               Gosu   2   0  1393
# 6290               k1ck       Keyd Stars   1         Keyd Stars   0   2  1393
# 6291            Infused            Choke   0            Infused   2   1  1393
# 6292          AlienTech  BulletsRage.Pro   0          AlienTech   2   0  1393
# 6293             Arcade       GUS-Gaming   0             Arcade   2   0  1393
# 6294              XENEX          UESmash   1            UESmash   0   2  1393
# 6295        HellRaisers               SK   1                 SK   6  16  1393
# 6296                NiP            Titan   1              Titan  17  19  1393
# 6297               k1ck  BulletsRage.Pro   1    BulletsRage.Pro  11  16  1393
# 6298                 SK    Natus Vincere   1      Natus Vincere  13  16  1393
# 6299                 SK       Virtus.pro   1         Virtus.pro  13  16  1393
# 6300                ACG             Enso   0                ACG   2   1  1393
# 6301   European Misfits         Reaction   0   European Misfits   2   0  1393
# 6302         Virtus.pro              TSM   1                TSM   3  16  1393
# 6303         GUS-Gaming             Enso   1               Enso  13  16  1393
# 6304                TSM           EnVyUs   0                TSM  16   9  1393
# 6305         Keyd Stars        AlienTech   1          AlienTech   1   2  1393
# 6306         Luminosity            Enemy   0         Luminosity  16  11  1393
# 6307       Leader-1 Red          Quintic   0       Leader-1 Red  16   8  1393
# 6308         Luminosity        Coastless   0         Luminosity  19  17  1393
# 6309                SoF             Gosu   0                SoF   2   0  1393
# 6310             Cloud9              CLG   1                CLG  11  16  1393
# 6311             Cloud9            Enemy   1              Enemy  10  16  1393
# 6312             Liquid        Coastless   0             Liquid  16  10  1393
# 6313       Leader-1 Red             Gosu   1               Gosu  13  16  1393
#
#       7                                                  8      9   \
# 0      3  http://www.hltv.org/match/2292372-cloud9-nip-e...   6234
# 1      3  http://www.hltv.org/match/2292374-fnatic-digni...   6235
# 2      3  http://www.hltv.org/match/2292377-ldlc-nip-esl...   6236
# 3      3  http://www.hltv.org/match/2292378-moldova-luxe...   6237
# 4      3  http://www.hltv.org/match/2292382-fnatic-nip-e...   6238
# 5      3  http://www.hltv.org/match/2292379-malta-armeni...   6239
# 6      1  http://www.hltv.org/match/2292383-lunatik-skdc...   6240
# %%
basicmatchinfo_reduced=basicmatchinfo[basicmatchinfo[9].isin(matches_unique).reset_index(drop=True)] #basic, but with shit deleted

# %%
basicmatchinfo_reduced
# Out:
#                      0                  1   2                 3   4   5   \
# 0                Cloud9                NiP   1               NiP   1   2
# 1                fnatic           dignitas   0            fnatic   2   0
# 2                   NiP               LDLC   0               NiP   2   1
# 3               Moldova         Luxembourg   0           Moldova   2   0
# 4                fnatic                NiP   1               NiP   1   2
# 5                 Malta            Armenia   0             Malta   2   0
# 7             Macedonia             Greece   0         Macedonia   2   1
# 12          mousesports            Epsilon   0       mousesports   2   0
# 16                myXMG            NO SIR!   0             myXMG   2   0
# 17             Slovenia      Faroe Islands   0          Slovenia   2   0
# 22          mousesports              myXMG   0       mousesports   2   1
# 23              NO SIR!          Nostalgie   0           NO SIR!   2   1
# 26                  NiP             ENCORE   0               NiP   2   0
# 27                myXMG            NO SIR!   0             myXMG   2   0
# 29    London Conspiracy        mousesports   1       mousesports   1   2
# 30                  NiP        mousesports   0               NiP   2   0
# 35             Slovakia           Bulgaria   0          Slovakia   2   1
# 36              noMERCY           A-Gaming   1          A-Gaming   0   2
# 37           OverGaming  London Conspiracy   0        OverGaming   2   0
# 47                PENTA            Cursive   0             PENTA  16   7
# 48                 dope              myXMG   0              dope   2   0
# 58               fnatic                dAT   0            fnatic   2   0
# 66                  ttc          Imaginary   0               ttc  16  13
# 67                 TMVG           NewStyle   0              TMVG  16  13
# 73                  ttc              PENTA   1             PENTA   9  16
# 74                 dope              Orbit   1             Orbit   8  16
# 76                 TMVG                MTW   0              TMVG  16  11
# 77              Epsilon              PENTA   0           Epsilon  16   6
# 79          HellRaisers               TMVG   0       HellRaisers  16  10
# 80                Orbit         CPH Wolves   1        CPH Wolves  21  26
# ...                 ...                ...  ..               ...  ..  ..
# 6284      Vega Squadron                ttc   0     Vega Squadron   2   0
# 6285         LDLC White              DenDD   1             DenDD   1   1
# 6286        KoN Finland        KoN Denmark   0       KoN Finland  16   2
# 6287           FlipSid3               CSGL   0          FlipSid3   2   1
# 6288                SoF       Leader-1 Red   0               SoF   2   1
# 6289               Gosu            Quintic   0              Gosu   2   0
# 6290               k1ck         Keyd Stars   1        Keyd Stars   0   2
# 6291            Infused              Choke   0           Infused   2   1
# 6292          AlienTech    BulletsRage.Pro   0         AlienTech   2   0
# 6293             Arcade         GUS-Gaming   0            Arcade   2   0
# 6294              XENEX            UESmash   1           UESmash   0   2
# 6295        HellRaisers                 SK   1                SK   6  16
# 6296                NiP              Titan   1             Titan  17  19
# 6297               k1ck    BulletsRage.Pro   1   BulletsRage.Pro  11  16
# 6298                 SK      Natus Vincere   1     Natus Vincere  13  16
# 6299                 SK         Virtus.pro   1        Virtus.pro  13  16
# 6300                ACG               Enso   0               ACG   2   1
# 6301   European Misfits           Reaction   0  European Misfits   2   0
# 6302         Virtus.pro                TSM   1               TSM   3  16
# 6303         GUS-Gaming               Enso   1              Enso  13  16
# 6304                TSM             EnVyUs   0               TSM  16   9
# 6285   Friday, October 23rd 2015
# 6286   Friday, October 23rd 2015
# 6287   Friday, October 23rd 2015
# 6288   Sunday, October 25th 2015
# 6289   Sunday, October 25th 2015
# 6290   Sunday, October 25th 2015
# 6291   Sunday, October 25th 2015
# 6292   Sunday, October 25th 2015
# 6293   Sunday, October 25th 2015
# 6294   Sunday, October 25th 2015
# 6295   Sunday, October 25th 2015
# 6296   Sunday, October 25th 2015
# 6297   Sunday, October 25th 2015
# 6298   Sunday, October 25th 2015
# 6299   Sunday, October 25th 2015
# 6300   Sunday, October 25th 2015
# 6301   Sunday, October 25th 2015
# 6302   Sunday, October 25th 2015
# 6303   Sunday, October 25th 2015
# 6304   Sunday, October 25th 2015
# 6305   Sunday, October 25th 2015
# 6306   Sunday, October 25th 2015
# 6307   Sunday, October 25th 2015
# 6308   Sunday, October 25th 2015
# 6309   Sunday, October 25th 2015
# 6310   Sunday, October 25th 2015
# 6311   Sunday, October 25th 2015
# 6312   Sunday, October 25th 2015
# 6313   Sunday, October 25th 2015
#
# [3973 rows x 11 columns]

# %%
#Now, time to create a function that creates the desired matricies


#Calling dataframes by TeamName
def team_databasic(team): 
    dfbasic = basicmatchinfo_reduced.loc[(basicmatchinfo_reduced.ix[:,0] == team) |  (basicmatchinfo_reduced.ix[:,1] == team) ]
    return(dfbasic.reset_index(drop=True))

def team_datadetailed(team): 
    dfdetailed = detailedgamedata.loc[(detailedgamedata.ix[:,'Team1'] == team) |  (detailedgamedata.ix[:,'Team2'] == team) ]
    return(dfdetailed.reset_index(drop=True))
team_datadetailed('Natus Vincere')
# Out:
#        ID                                               Link  MatchID  \
# 0     116  http://www.hltv.org/match/2292484-natus-vincer...     6367
# 1     117  http://www.hltv.org/match/2292484-natus-vincer...     6367
# 2     118  http://www.hltv.org/match/2292525-fnatic-natus...     6368
# 3     119  http://www.hltv.org/match/2292525-fnatic-natus...     6368
# 4     122  http://www.hltv.org/match/2292527-natus-vincer...     6371
# 5     123  http://www.hltv.org/match/2292527-natus-vincer...     6371
# 6     124  http://www.hltv.org/match/2292527-natus-vincer...     6371
# 7     125  http://www.hltv.org/match/2292528-fnatic-natus...     6373
# 8     126  http://www.hltv.org/match/2292528-fnatic-natus...     6373
# 9     127  http://www.hltv.org/match/2292528-fnatic-natus...     6373
# 10    128  http://www.hltv.org/match/2292528-fnatic-natus...     6373
# 11    265  http://www.hltv.org/match/2292767-natus-vincer...     6589
# 12    266  http://www.hltv.org/match/2292768-natus-vincer...     6590
# 13    292  http://www.hltv.org/match/2292816-natus-vincer...     6626
# 14    293  http://www.hltv.org/match/2292818-natus-vincer...     6628
# 15    295  http://www.hltv.org/match/2292813-titan-natus-...     6638
# 16    313  http://www.hltv.org/match/2292852-natus-vincer...     6667
# 17    314  http://www.hltv.org/match/2292852-natus-vincer...     6667
# 18    321  http://www.hltv.org/match/2292848-natus-vincer...     6673
# 19    333  http://www.hltv.org/match/2292877-virtuspro-na...     6684
# 20    346  http://www.hltv.org/match/2292893-natus-vincer...     6696
def subset(team,i):
    return(team_datadetailed(team)[team_datadetailed(team)['MatchID']==(ID(team)[i])].reset_index(drop=True))
subset('Natus Vincere',0)

#this is NA'Vis 0th game.
# Out:
#     ID                                               Link  MatchID      Map  \
# 0  116  http://www.hltv.org/match/2292484-natus-vincer...     6367    dust2
# 1  117  http://www.hltv.org/match/2292484-natus-vincer...     6367  inferno
#
#    MapNumber          Team1        Team2  1  1.1  1.2  ...    1.83   1.84  \
# 0          1  Natus Vincere  HellRaisers  0   16    6  ...    35.7  Empty
# 1          2  Natus Vincere  HellRaisers  0   16   14  ...    39.1  Empty
#
#    1.85   1.86  1.87   1.88  1.89   1.90  1.91   1.92
# 0  66.7  Empty  66.7  Empty  41.7  Empty  57.1  14:30
# 1  56.5  Empty  26.3  Empty  28.6  Empty  56.3  14:30
#
# [2 rows x 100 columns]

# %%
#Making the list for each match
list0=[0,0,0,0,0]
len(list0)

def listmaker(team,i):
    
    listlist=[]
        
    listlist.append(len(subset(team,i)['ID']))
        
    if(subset(team,i).loc[:,'Team1'][0])==team:                      # [✔]
        listlist.append(subset(team,i).loc[:,'Team1'][0])    # [✔]
    if(subset(team,i).loc[:,'Team2'][0])==team:
        listlist.append(subset(team,i).loc[:,'Team2'][0])    # [✔]
            
    if(subset(team,i).loc[:,'Team1'][0])==team:
        listlist.append(subset(team,i).loc[:,'Team2'][0]) # [✔]
    if(subset(team,i).loc[:,'Team2'][0])==team:
        listlist.append(subset(team,i).loc[:,'Team1'][0] )# [✔]
        
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
   
    a=subset(team,i)['Map'].tolist()
    a=a+[0]*(len(list0)-len(a))    
    
    a.extend(listlist)
    
    a.append(subset(team,i)['MatchID'][0])
    
    return(a)
        
listmaker('NiP',0)

#ayyyyy

#this makes a list which has everything we need for a certain match_ID (all maps included, ass well as empty 'slots'w)
# Out:
# ['nuke', 'dust2', 'cobblestone', 0, 0, 3, 'NiP', 'Cloud9', 6234]

# %%
#now to loop over each list above....

def team_matrix(team):
    listoflists=[]
    for id in range(len(ID(team))):
        listoflists.append(listmaker(team,id))
        #aarray=pd.DataFrame(listoflists)
        #aarray.columns=['Map1','Map2','Map3','Map4','Map5','Best of "x"','TeamID','OpponentID','MatchID']
    if len(pd.DataFrame(listoflists).columns)==9:
        return(pd.DataFrame(data=(listoflists), columns=['Map1','Map2','Map3','Map4','Map5',
                                                         'Best of "x"','TeamID','OpponentID','MatchID']))
        
    elif len(pd.DataFrame(listoflists).columns)==10:
        return(pd.DataFrame(data=(listoflists), columns=['Map1','Map2','Map3','Map4','Map5',
                                                         'Best of "x"','TeamID','OpponentID','MatchID', 'NAN']))
    elif len(pd.DataFrame(listoflists).columns)==11:
        return(pd.DataFrame(data=(listoflists), columns=['Map1','Map2','Map3','Map4','Map5',
                                                         'Best of "x"','TeamID','OpponentID','MatchID', 'NAN','NAN2']))
    
#I'm doing all this elif shit becuase the data was dirty and some teams had random nans/ caused above functions to not work correctly
#so, this is like a temporary (bad) fix.
#team_matrix('k1ck'),

# %%
team1=detailedgamedata['Team1'].tolist()
team2=detailedgamedata['Team2'].tolist()
teams=team1+team2
teams_unique=np.unique(teams).tolist()
teams_unique


#exceptions...
list2=[ x for x in teams_unique if "?" not in x ] #'?' caused a crash

#test=['NiP','Cloud9']

# %%
#for name in list2:
#    user_data = team_matrix(name)   # This will create a copy dataframe.
#    user_data.to_csv('.'.join([name,'csv']), delimiter=',', encoding='utf-8')
'Excel spreadsheet maker'
# Out:
# 'Excel spreadsheet maker'

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# # Starting Roster one now...

# %%
'Time to define the above in a different way- by defining a team by roster, not org'


# I think the best thing to do fisrt is to make a list of all unique rosters...
#Can do this by partitioning the original datasets into the members only...

#Partition:
players=np.array(detailedgamedata.ix[:,[5,15,19,23,27,31,6,35,39,43,47,51]]) #all players from both teams
players1=detailedgamedata.ix[:,[15,19,23,27,31]] #team 1 players
players2=detailedgamedata.ix[:,[35,39,43,47,51]].dropna()  #was causing issues below
players1=players1.drop(players1.index[740]) #aligns this dataframe with teh above one.

players1=np.array(players1) #had some issues doing it in one step, so did this here.(I know it seems redundant)
players2=np.array(players2)
#the splitting here was done for side-1, side-2, or team-1, team-2. Bad naming, really on my part 'playersx'


print(len(players1))
print(len(players2))

print(players[741])
print(players1[740])
print(players2[740])
# Out:
# 6562
# 6562
# ['CPH Wolves' "Casper 'cadiaN' Møller" "Markus 'Kjaerbye' Kjærbye"
#  "Jesper 'TENZKI' Plougmann" "Jacob 'Pimp' Winneche"
#  "Lukas 'gla1ve' Rossander" 'HellRaisers' "Mihail 'Dosia' Stolyarov"
#  "Aleksandr 's1mple' Kostyliev" "Yegor 'markeloff' Markelov"
#  "Kirill 'ANGE1' Karasiow" "Emil 'kUcheR' Akhundov"]
# ["Casper 'cadiaN' Møller" "Markus 'Kjaerbye' Kjærbye"
#  "Jesper 'TENZKI' Plougmann" "Jacob 'Pimp' Winneche"
#  "Lukas 'gla1ve' Rossander"]
# ["Mihail 'Dosia' Stolyarov" "Aleksandr 's1mple' Kostyliev"
#  "Yegor 'markeloff' Markelov" "Kirill 'ANGE1' Karasiow"
#  "Emil 'kUcheR' Akhundov"]

# %%
def rowmaker(i, array):
    return(np.sort(array[i]))

#orders each row alphabetically from a chosen team (array-players1/players2) and a chosen in index(i)
#the index means I can iterate it below 
rowmaker(1, players2)
#players2
# Out:
# array(["Adam 'friberg' Friberg", "Christopher 'GeT_RiGhT' Alesund",
#        "Patrik 'f0rest' Lindberg", "Richard 'Xizt' Landström",
#        "Robin 'Fifflaren' Johansson"], dtype=object)

# %%
#note: yes I know I should have done array_maker and array_maker2 in one go, but I couldn't get the 
#if, elif statement for 'team 1' and 'team 2' to work.

def array_maker(): #this iterates across all the rows for (rowmaker) and puts them back together
    emptylist=[]
    for i in range(len(players1)):
        emptylist.append(rowmaker(i,players1))
        dataframe=pd.DataFrame(data=(emptylist), columns=['Player1','Player2','Player3','Player4','Player5'])
        dataframe.insert(0, 'Team1', pd.DataFrame(players).ix[:,0])
    return(dataframe)
#array_maker()

# %%
def array_maker2(): #this iterates across all the rows for (rowmaker) and puts them back together
    emptylist2=[]
    for i in range(len(players2)):
        emptylist2.append(rowmaker(i,players2))
        dataframe2=pd.DataFrame(data=(emptylist2), columns=['Player1','Player2','Player3','Player4','Player5'])
        dataframe2.insert(0, 'Team2', pd.DataFrame(players).ix[:,6])
    return(dataframe2)
#array_maker2()

#I would like to combine these two into a single function, but results over form atm

# %%
array1=array_maker()
array2=array_maker2()

# %%
combination = pd.concat([array1,array2], keys=['Team1', 'Team2']) #this form used to make unique_list easily, but wont 
#use this form later on (would like to reconstruct dataframe)
combination.drop(['Team1','Team2'], axis = 1, inplace = True, errors = 'ignore')

#Stacks each of these arrays upon each other, with relevent key


combination_unique=combination.drop_duplicates()

print(len(combination_unique))
print(len(combination))

#Duplicates deleted :many
# Out:
# 1745
# 13124

# %%
Original_frame= pd.concat([array1, array2], axis=1, join_axes=[array1.index])
Original_frame['Map']=detailedgamedata.ix[:,3]
Original_frame['Map number']=detailedgamedata.ix[:,4]
Original_frame['ID']=detailedgamedata.ix[:,2]
Original_frame

#This is a reconstruction of what I wanted from the very start...
'Use this as a functional table from which to work with, like detailedgamedatabefore-DONT CHANGE'
# Out:
# 'Use this as a functional table from which to work with, like detailedgamedatabefore-DONT CHANGE'

# %%
'Below is experimenting in dictionary-CAN CHANGE'
# Out:
# 'Below is experimenting in dictionary-CAN CHANGE'

# %%
#make dictionary of rosters

from collections import defaultdict

rosters = defaultdict(list)

for i in range(len(combination_unique)):
    rosters[i].append(str(combination_unique.ix[i,1:6]))
    
#rosters exists, and contains all rosters as a string...

# %%
#Do all of the original shit, replace 'team' with dictionary entry.

def team_datadetailed(roster): 
    for i in range(len(Original_frame)):
        dfdetailed = Original_frame.loc[(str(Original_frame.ix[i,1:6]) == roster) | (str(Original_frame.ix[i,8:12]) == roster)]
    return(dfdetailed.reset_index(drop=True))
#team_datadetailed(rosters[0])

# %%
if str(Original_frame.ix[0,1:6])==rosters[0]:
    print('yes')
else: 
    print('no')
# Out:
# no

# %%
str(Original_frame.ix[0,1:6])
# Out:
# "Player1    Jordan 'n0thing' Gilbert\nPlayer2      Kory 'SEMPHIS' Friesen\nPlayer3      Mike 'shroud' Grzesiek\nPlayer4      Sean 'seang@res' Gares\nPlayer5       Spencer 'Hiko' Martin\nName: 0, dtype: object"

# %%
rosters[0]

#the key is fucking it up, but then a dicionary needs a key
# Out:
# ["Player1    Jordan 'n0thing' Gilbert\nPlayer2      Kory 'SEMPHIS' Friesen\nPlayer3      Mike 'shroud' Grzesiek\nPlayer4      Sean 'seang@res' Gares\nPlayer5       Spencer 'Hiko' Martin\nName: (Team1, 0), dtype: object"]

# %%
'Problem is that strings arent the same. You will need to make them the same,or find another solution'
# Out:
# 'Problem is that strings arent the same. You will need to make them the same,or find another solution'

# %%
#--------------------------------------------------------------------------------------------------------------------

# %%
combination_unique.ix[0,3]
# Out:
# "Kory 'SEMPHIS' Friesen"

# %%
'Below try Maxs solution, if works can delete above section'
# Out:
# 'Below try Maxs solution, if works can delete above section'

# %%
#attempting to do what Max said in messenger
